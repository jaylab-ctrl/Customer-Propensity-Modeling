# %% [markdown]
# # Predicting Customer Propensity to Engage

# %% [markdown]
# ##1. Installing and Importing Libraries

# %%
# !pip install lightgbm
# !pip install datetime
# !pip install plotly
# !pip install more_itertools
# !pip install imblearn
# !pip install fast_ml
# !pip install evalml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.9/dist-packages (3.3.5)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.9/dist-packages (from lightgbm) (1.2.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from lightgbm) (0.40.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from lightgbm) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from lightgbm) (1.22.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datetime
#   Downloading DateTime-5.1-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 KB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.9/dist-packages (from datetime) (2022.7.1)
# Collecting zope.interface
#   Downloading zope.interface-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 KB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from zope.interface->datetime) (67.6.0)
# Installing collected packages: zope.interface, datetime
# Successfully installed datetime-5.1 zope.interface-6.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (5.13.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly) (8.2.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.9/dist-packages (9.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.9/dist-packages (from imblearn) (0.10.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn->imblearn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn->imblearn) (1.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn->imblearn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn->imblearn) (1.22.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn->imblearn) (1.1.1)
# Installing collected packages: imblearn
# Successfully installed imblearn-0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fast_ml
#   Downloading fast_ml-3.68-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 KB 2.4 MB/s eta 0:00:00
# Installing collected packages: fast_ml
# Successfully installed fast_ml-3.68
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting evalml
#   Downloading evalml-0.71.0-py3-none-any.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 56.8 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from evalml) (8.1.3)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from evalml) (2.2.1)
# Collecting catboost>=1.1.1
#   Downloading catboost-1.1.1-cp39-none-manylinux1_x86_64.whl (76.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets>=7.5 in /usr/local/lib/python3.9/dist-packages (from evalml) (7.7.1)
# Requirement already satisfied: xgboost>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from evalml) (1.7.4)
# Collecting black[jupyter]>=22.3.0
#   Downloading black-23.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 49.6 MB/s eta 0:00:00
# Requirement already satisfied: pyzmq>=20.0.0 in /usr/local/lib/python3.9/dist-packages (from evalml) (23.2.1)
# Requirement already satisfied: graphviz>=0.13 in /usr/local/lib/python3.9/dist-packages (from evalml) (0.20.1)
# Collecting shap>=0.40.0
#   Downloading shap-0.41.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.4/572.4 KB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.9/dist-packages (from evalml) (23.0)
# Requirement already satisfied: imbalanced-learn>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from evalml) (0.10.1)
# Collecting vowpalwabbit>=8.11.0
#   Downloading vowpalwabbit-9.8.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 55.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.9/dist-packages (from evalml) (1.22.4)
# Collecting sktime>=0.15.0
#   Downloading sktime-0.16.1-py3-none-any.whl (16.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 66.7 MB/s eta 0:00:00
# Collecting kaleido>=0.1.0
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: dask!=2022.10.1,>=2022.2.0 in /usr/local/lib/python3.9/dist-packages (from evalml) (2022.12.1)
# Collecting colorama>=0.4.4
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from evalml) (1.10.1)
# Collecting pmdarima>=1.8.5
#   Downloading pmdarima-2.0.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 64.2 MB/s eta 0:00:00
# Collecting featuretools>=1.16.0
#   Downloading featuretools-1.23.0-py3-none-any.whl (555 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.7/555.7 KB 41.5 MB/s eta 0:00:00
# Collecting texttable>=1.6.2
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: matplotlib>=3.3.3 in /usr/local/lib/python3.9/dist-packages (from evalml) (3.7.1)
# Requirement already satisfied: scikit-learn>=1.2.2 in /usr/local/lib/python3.9/dist-packages (from evalml) (1.2.2)
# Collecting holidays<0.21,>=0.13
#   Downloading holidays-0.20-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.5/226.5 KB 21.1 MB/s eta 0:00:00
# Collecting pandas>=1.5.0
#   Downloading pandas-1.5.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 79.3 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.6 in /usr/local/lib/python3.9/dist-packages (from evalml) (3.0)
# Collecting woodwork>=0.22.0
#   Downloading woodwork-0.22.0-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.8/232.8 KB 23.2 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels>=0.12.2 in /usr/local/lib/python3.9/dist-packages (from evalml) (0.13.5)
# Collecting nlp-primitives>=2.9.0
#   Downloading nlp_primitives-2.10.0-py3-none-any.whl (44.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 MB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: lightgbm>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from evalml) (3.3.5)
# Collecting scikit-optimize>=0.9.0
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 KB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from evalml) (5.13.1)
# Collecting lime>=0.2.0.1
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 KB 26.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: seaborn>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from evalml) (0.12.2)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from evalml) (2.0.1)
# Collecting category-encoders<=2.5.1.post0,>=2.2.2
#   Downloading category_encoders-2.5.1.post0-py2.py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 KB 7.6 MB/s eta 0:00:00
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting pathspec>=0.9.0
#   Downloading pathspec-0.11.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.9/dist-packages (from black[jupyter]>=22.3.0->evalml) (4.5.0)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.9/dist-packages (from black[jupyter]>=22.3.0->evalml) (3.1.1)
# Collecting tokenize-rt>=3.2.0
#   Downloading tokenize_rt-5.0.0-py2.py3-none-any.whl (5.8 kB)
# Requirement already satisfied: ipython>=7.8.0 in /usr/local/lib/python3.9/dist-packages (from black[jupyter]>=22.3.0->evalml) (7.9.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from catboost>=1.1.1->evalml) (1.16.0)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.9/dist-packages (from category-encoders<=2.5.1.post0,>=2.2.2->evalml) (0.5.3)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from dask!=2022.10.1,>=2022.2.0->evalml) (2023.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.9/dist-packages (from dask!=2022.10.1,>=2022.2.0->evalml) (6.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.9/dist-packages (from dask!=2022.10.1,>=2022.2.0->evalml) (1.3.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.9/dist-packages (from dask!=2022.10.1,>=2022.2.0->evalml) (0.12.0)
# Requirement already satisfied: tqdm>=4.32.0 in /usr/local/lib/python3.9/dist-packages (from featuretools>=1.16.0->evalml) (4.65.0)
# Requirement already satisfied: distributed!=2022.10.1,>=2022.2.0 in /usr/local/lib/python3.9/dist-packages (from featuretools>=1.16.0->evalml) (2022.12.1)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.9/dist-packages (from featuretools>=1.16.0->evalml) (5.9.4)
# Requirement already satisfied: hijri-converter in /usr/local/lib/python3.9/dist-packages (from holidays<0.21,>=0.13->evalml) (2.2.4)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.9/dist-packages (from holidays<0.21,>=0.13->evalml) (0.3.1)
# Requirement already satisfied: PyMeeus in /usr/local/lib/python3.9/dist-packages (from holidays<0.21,>=0.13->evalml) (0.5.12)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from holidays<0.21,>=0.13->evalml) (2.8.2)
# Requirement already satisfied: convertdate>=2.3.0 in /usr/local/lib/python3.9/dist-packages (from holidays<0.21,>=0.13->evalml) (2.4.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn>=0.9.1->evalml) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn>=0.9.1->evalml) (3.1.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.5->evalml) (3.0.6)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.5->evalml) (5.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.5->evalml) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.5->evalml) (3.6.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets>=7.5->evalml) (0.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from lightgbm>=2.3.1->evalml) (0.40.0)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.9/dist-packages (from lime>=0.2.0.1->evalml) (0.19.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.3->evalml) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.3->evalml) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.3->evalml) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.3->evalml) (4.39.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.3->evalml) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.3->evalml) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.3->evalml) (8.4.0)
# Requirement already satisfied: nltk>=3.4.5 in /usr/local/lib/python3.9/dist-packages (from nlp-primitives>=2.9.0->evalml) (3.8.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.5.0->evalml) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=5.0.0->evalml) (8.2.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.9/dist-packages (from pmdarima>=1.8.5->evalml) (67.6.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.9/dist-packages (from pmdarima>=1.8.5->evalml) (0.29.33)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from pmdarima>=1.8.5->evalml) (1.26.15)
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from shap>=0.40.0->evalml) (0.56.4)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated>=1.2.13->sktime>=0.15.0->evalml) (1.15.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from distributed!=2022.10.1,>=2022.2.0->featuretools>=1.16.0->evalml) (3.1.2)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.9/dist-packages (from distributed!=2022.10.1,>=2022.2.0->featuretools>=1.16.0->evalml) (2.2.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from distributed!=2022.10.1,>=2022.2.0->featuretools>=1.16.0->evalml) (1.7.0)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from distributed!=2022.10.1,>=2022.2.0->featuretools>=1.16.0->evalml) (1.0.5)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.9/dist-packages (from distributed!=2022.10.1,>=2022.2.0->featuretools>=1.16.0->evalml) (2.4.0)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from distributed!=2022.10.1,>=2022.2.0->featuretools>=1.16.0->evalml) (1.0.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.9/dist-packages (from distributed!=2022.10.1,>=2022.2.0->featuretools>=1.16.0->evalml) (6.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.3->evalml) (3.15.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->evalml) (6.1.12)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=7.8.0->black[jupyter]>=22.3.0->evalml) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=7.8.0->black[jupyter]>=22.3.0->evalml) (4.8.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 75.1 MB/s eta 0:00:00
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=7.8.0->black[jupyter]>=22.3.0->evalml) (2.0.10)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=7.8.0->black[jupyter]>=22.3.0->evalml) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=7.8.0->black[jupyter]>=22.3.0->evalml) (2.14.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=7.8.0->black[jupyter]>=22.3.0->evalml) (0.7.5)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk>=3.4.5->nlp-primitives>=2.9.0->evalml) (2022.10.31)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->shap>=0.40.0->evalml) (0.39.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.12->lime>=0.2.0.1->evalml) (2023.3.21)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.12->lime>=0.2.0.1->evalml) (2.25.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.12->lime>=0.2.0.1->evalml) (1.4.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (6.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=7.8.0->black[jupyter]>=22.3.0->evalml) (0.8.3)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (5.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (0.16.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (5.3.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (21.3.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (6.5.4)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (0.17.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (1.8.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=7.8.0->black[jupyter]>=22.3.0->evalml) (0.2.6)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.9/dist-packages (from zict>=0.1.3->distributed!=2022.10.1,>=2022.2.0->featuretools>=1.16.0->evalml) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->distributed!=2022.10.1,>=2022.2.0->featuretools>=1.16.0->evalml) (2.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython>=7.8.0->black[jupyter]>=22.3.0->evalml) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (21.2.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (0.8.4)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (1.2.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (4.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (0.2.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (4.11.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (0.7.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (6.0.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (2.16.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5->evalml) (2.21)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283859 sha256=121680c289d247bd306e6b138f2f6e50c2a71c243a05e9da5d391ed1f48ded00
#   Stored in directory: /root/.cache/pip/wheels/ed/d7/c9/5a0130d06d6310bc6cbe55220e6e72dcb8c4eff9a478717066
# Successfully built lime
# Installing collected packages: texttable, kaleido, vowpalwabbit, tokenize-rt, slicer, pyaml, pathspec, mypy-extensions, jedi, deprecated, colorama, pandas, holidays, black, woodwork, sktime, shap, scikit-optimize, lime, catboost, pmdarima, category-encoders, featuretools, nlp-primitives, evalml
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.4
#     Uninstalling pandas-1.4.4:
#       Successfully uninstalled pandas-1.4.4
#   Attempting uninstall: holidays
#     Found existing installation: holidays 0.21.13
#     Uninstalling holidays-0.21.13:
#       Successfully uninstalled holidays-0.21.13
# Successfully installed black-23.1.0 catboost-1.1.1 category-encoders-2.5.1.post0 colorama-0.4.6 deprecated-1.2.13 evalml-0.71.0 featuretools-1.23.0 holidays-0.20 jedi-0.18.2 kaleido-0.2.1 lime-0.2.0.1 mypy-extensions-1.0.0 nlp-primitives-2.10.0 pandas-1.5.3 pathspec-0.11.1 pmdarima-2.0.3 pyaml-21.10.1 scikit-optimize-0.9.0 shap-0.41.0 sktime-0.16.1 slicer-0.0.7 texttable-1.6.7 tokenize-rt-5.0.0 vowpalwabbit-9.8.0 woodwork-0.22.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from fast_ml.utilities import display_all
from fast_ml import eda
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.colors import n_colors
from plotly.subplots import make_subplots
import datetime as dt
from scipy import stats
from more_itertools import unique_everseen
from sklearn.covariance import EllipticEnvelope
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split as tts
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
#import evalml
#from evalml import AutoMLSearch
import pickle

# %% [markdown]
# ##2. Data Loading & Analysis

# %%
orders_df = pd.read_csv('olist_orders_dataset.csv', engine='python')
order_items = pd.read_csv('olist_order_items_dataset.csv', engine='python')
order_reviews = pd.read_csv('olist_order_reviews_dataset.csv', engine='python')
products = pd.read_csv('olist_products_dataset.csv', engine='python')
product_category = pd.read_csv('product_category_name_translation.csv', engine='python')
customer = pd.read_csv('olist_customers_dataset.csv', engine='python')
payments = pd.read_csv('olist_order_payments_dataset.csv', engine='python')
sellers = pd.read_csv('olist_sellers_dataset.csv', engine='python')

# %%
orders_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 0        delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
# ...            ...                      ...                  ...
# 99436    delivered      2017-03-09 09:54:05  2017-03-09 09:54:05
# 99437    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 99438    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 99439    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 99440    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 99436          2017-03-10 11:18:03           2017-03-17 15:08:01
# 99437          2018-02-07 23:22:42           2018-02-28 17:37:56
# 99438          2017-08-28 20:52:26           2017-09-21 11:24:17
# 99439          2018-01-12 15:35:03           2018-01-25 23:32:54
# 99440          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date
# 0               2017-10-18 00:00:00
# 1               2018-08-13 00:00:00
# 2               2018-09-04 00:00:00
# 3               2017-12-15 00:00:00
# 4               2018-02-26 00:00:00
# ...                             ...
# 99436           2017-03-28 00:00:00
# 99437           2018-03-02 00:00:00
# 99438           2017-09-27 00:00:00
# 99439           2018-02-15 00:00:00
# 99440           2018-04-03 00:00:00
#
# [99441 rows x 8 columns]

# %%
order_items.head(10)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
# 5  00048cc3ae777c65dbb7d2a0634bc1ea              1
# 6  00054e8431b9d7675808bcb819fb4a32              1
# 7  000576fe39319847cbb9d288c5617fa6              1
# 8  0005a1a1728c9d785b8e2b08b904576c              1
# 9  0005f50442cb953dcd1d21e1fb923495              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# 5  ef92defde845ab8450f9d70c526ef70f  6426d21aca402a131fc0a5d0960a3c90
# 6  8d4f2bb7e93e6710a28f34fa83ee7d28  7040e82f899a04d1b434b795a43b4617
# 7  557d850972a7d6f792fd18ae1400d9b6  5996cddab893a4652a15592fb58ab8db
# 8  310ae3c140ff94b03219ad0adc3c778f  a416b6a846a11724393025641d4edd5e
# 9  4535b0e1091c278dfd193e5a1d63b39f  ba143b05f0110f0dc71ad71b4466ce92
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14
# 5  2017-05-23 03:55:27   21.90          12.69
# 6  2017-12-14 12:10:31   19.90          11.85
# 7  2018-07-10 12:30:45  810.00          70.75
# 8  2018-03-26 18:31:29  145.95          11.65
# 9  2018-07-06 14:10:56   53.99          11.40

# %%
order_reviews.head(10)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 5  15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6  07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# 7  7c6400515c67679fbee952a7525281ef  c31a859e34e3adac22f376954e19b39d
# 8  a3f6f7f6f433de0aefbb97da197c554c  9c214ac970e84273583ab523dfafd09b
# 9  8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
# 5             1                  NaN
# 6             5                  NaN
# 7             5                  NaN
# 8             5                  NaN
# 9             4            recomendo
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# 5                                                NaN  2018-04-13 00:00:00
# 6                                                NaN  2017-07-16 00:00:00
# 7                                                NaN  2018-08-14 00:00:00
# 8                                                NaN  2017-05-17 00:00:00
# 9  aparelho eficiente. no site a marca do aparelh...  2018-05-22 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53
# 5     2018-04-16 00:39:37
# 6     2017-07-18 19:30:34
# 7     2018-08-14 21:36:06
# 8     2017-05-18 12:05:37
# 9     2018-05-23 16:45:47

# %%
products.head(10)
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
# 5  41d3672d4792049fa1779bb35283ed13  instrumentos_musicais
# 6  732bd381ad09e530fe0a5f457d81becb             cool_stuff
# 7  2548af3e6e77a690cf3eb6368e9ab61e       moveis_decoracao
# 8  37cc742be07708b53a98702e77a21a02       eletrodomesticos
# 9  8c92109888e8cdf9d66dc7e463025574             brinquedos
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
# 5                 60.0                       745.0                 1.0
# 6                 56.0                      1272.0                 4.0
# 7                 56.0                       184.0                 2.0
# 8                 57.0                       163.0                 1.0
# 9                 36.0                      1156.0                 1.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0
# 5             200.0               38.0                5.0              11.0
# 6           18350.0               70.0               24.0              44.0
# 7             900.0               40.0                8.0              40.0
# 8             400.0               27.0               13.0              17.0
# 9             600.0               17.0               10.0              12.0

# %%
products.dtypes
# Out:
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %%
product_category.head(10)
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor
# 5           esporte_lazer                sports_leisure
# 6              perfumaria                     perfumery
# 7   utilidades_domesticas                    housewares
# 8               telefonia                     telephony
# 9      relogios_presentes                 watches_gifts

# %%
product_category.dtypes
# Out:
# product_category_name            object
# product_category_name_english    object
# dtype: object

# %%
customer.head(10)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5  879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6  fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7  5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8  5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9  4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
# 5                     89254         jaragua do sul             SC
# 6                      4534              sao paulo             SP
# 7                     35182                timoteo             MG
# 8                     81560               curitiba             PR
# 9                     30575         belo horizonte             MG

# %%
payments.head(10)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# 5  298fcdf1f73eb413e4d26d01b25bc1cd                   1  credit_card
# 6  771ee386b001f06208a7419e4fc1bbd7                   1  credit_card
# 7  3d7239c394a212faae122962df514ac7                   1  credit_card
# 8  1f78449c87a54faf9e96e88ba1491fa9                   1  credit_card
# 9  0573b5e23cbd798006520e1d5b4c6714                   1       boleto
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45
# 5                     2          96.12
# 6                     1          81.16
# 7                     3          51.84
# 8                     6         341.09
# 9                     1          51.95

# %%
categories = products.merge(product_category, on = 'product_category_name', how = 'left')

# %%
categories
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                     40.0                       287.0                 1.0
# 1                     44.0                       276.0                 1.0
# 2                     46.0                       250.0                 1.0
# 3                     27.0                       261.0                 1.0
# 4                     37.0                       402.0                 4.0
# ...                    ...                         ...                 ...
# 32946                 45.0                        67.0                 2.0
# 32947                 41.0                       971.0                 1.0
# 32948                 50.0                       799.0                 1.0
# 32949                 60.0                       156.0                 2.0
# 32950                 58.0                       309.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 0                 225.0               16.0               10.0
# 1                1000.0               30.0               18.0
# 2                 154.0               18.0                9.0
# 3                 371.0               26.0                4.0
# 4                 625.0               20.0               17.0
# ...                 ...                ...                ...
# 32946           12300.0               40.0               40.0
# 32947            1700.0               16.0               19.0
# 32948            1400.0               27.0                7.0
# 32949             700.0               31.0               13.0
# 32950            2083.0               12.0                2.0
#
#        product_width_cm product_category_name_english
# 0                  14.0                     perfumery
# 1                  20.0                           art
# 2                  15.0                sports_leisure
# 3                  26.0                          baby
# 4                  13.0                    housewares
# ...                 ...                           ...
# 32946              40.0               furniture_decor
# 32947              16.0     construction_tools_lights
# 32948              27.0                bed_bath_table
# 32949              20.0         computers_accessories
# 32950               7.0                bed_bath_table
#
# [32951 rows x 10 columns]

# %%
sellers.head(10)
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
# 5  c240c4061717ac1806ae6ee72be3533b                   20920
# 6  e49c26c3edfa46d227d5121a6b6e4d37                   55325
# 7  1b938a7ec6ac5061a66a3766e0e75f90                   16304
# 8  768a86e36ad6aae3d03ee3c6433d61df                    1529
# 9  ccc4bbb5f32a6ab2b7066a4130f114e3                   80310
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP
# 5     rio de janeiro           RJ
# 6             brejao           PE
# 7          penapolis           SP
# 8          sao paulo           SP
# 9           curitiba           PR

# %%
orders = orders_df.merge(customer, on="customer_id")
orders = orders.merge(order_items, on="order_id")
orders = orders.merge(products, on="product_id")
orders = orders.merge(product_category, on="product_category_name")
orders = orders.merge(payments, on="order_id")
orders = orders.merge(sellers, on="seller_id")
orders = orders.merge(order_reviews, on="order_id")

# %%
orders.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 4  0e7e841ddf8f8f2de2bad69267ecfbcf  26c7ac168e1433912a51b924fbd34d34
# 5  bfc39df4f36c3693ff3b63fcbea9e90a  53904ddbea91e1e92b2b3f1d09a7af86
# 6  5f49f31e537f8f1a496454b48edbe34d  a7260a6ccba78544ccfaf43f920b7240
# 7  5f49f31e537f8f1a496454b48edbe34d  a7260a6ccba78544ccfaf43f920b7240
# 8  1fa40f202d5d233b6491e976c557b822  50fd5707c28d0a64dc20d67f937dd9ba
# 9  41c045db2d1876be9f05cf4a787693b2  a286f46d6e54cc0179bbb0ee07b0df5e
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2017-08-15 18:29:31  2017-08-15 20:05:16
# 4    delivered      2017-08-02 18:24:47  2017-08-02 18:43:15
# 5    delivered      2017-10-23 23:26:46  2017-10-25 02:14:11
# 6    delivered      2017-08-24 11:31:28  2017-08-24 11:45:25
# 7    delivered      2017-08-24 11:31:28  2017-08-24 11:45:25
# 8    delivered      2017-09-23 22:11:10  2017-09-23 22:25:11
# 9    delivered      2017-08-16 14:06:30  2017-08-16 14:55:20
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2017-08-17 15:28:33           2017-08-18 14:44:43
# 4          2017-08-04 17:35:43           2017-08-07 18:30:01
# 5          2017-10-27 16:48:46           2017-11-07 18:04:59
# 6          2017-08-25 14:17:55           2017-08-28 20:12:20
# 7          2017-08-25 14:17:55           2017-08-28 20:12:20
# 8          2017-09-26 17:27:54           2017-10-19 21:09:21
# 9          2017-08-18 15:41:40           2017-08-21 15:05:13
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 1           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 2           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 3           2017-08-28 00:00:00  3a51803cc0d012c3b5dc8b7528cb05f7
# 4           2017-08-15 00:00:00  ef0996a1a279c26e7ecbd737be23d235
# 5           2017-11-13 00:00:00  e781fdcc107d13d865fc7698711cc572
# 6           2017-09-14 00:00:00  7a1de9bde89aedca8c5fbad489c5571c
# 7           2017-09-14 00:00:00  7a1de9bde89aedca8c5fbad489c5571c
# 8           2017-11-13 00:00:00  35c6ec4630637b3ec0da6e587f245f83
# 9           2017-08-29 00:00:00  4e4fa2b85379e9db6dc59f873f0a9748
#
#    customer_zip_code_prefix  ... payment_value seller_zip_code_prefix  \
# 0                      3149  ...         18.12                   9350
# 1                      3149  ...          2.00                   9350
# 2                      3149  ...         18.59                   9350
# 3                      3366  ...         37.77                   9350
# 4                      2290  ...         37.77                   9350
# 5                     88032  ...         44.09                   9350
# 6                      1315  ...        127.45                   9350
# 7                      1315  ...        127.45                  14021
# 8                     69043  ...         50.05                   9350
# 9                      5640  ...         32.68                   9350
#
#       seller_city seller_state                         review_id review_score  \
# 0            maua           SP  a54f0611adc9ed256b57ede6b6eb5114            4
# 1            maua           SP  a54f0611adc9ed256b57ede6b6eb5114            4
# 2            maua           SP  a54f0611adc9ed256b57ede6b6eb5114            4
# 3            maua           SP  b46f1e34512b0f4c74a72398b03ca788            4
# 4            maua           SP  dc90f19c2806f1abba9e72ad3c350073            5
# 5            maua           SP  1bafb430e498b939f258b9c9dbdff9b1            3
# 6            maua           SP  8899ca945efd951c97107b4966289227            1
# 7  ribeirao preto           SP  8899ca945efd951c97107b4966289227            1
# 8            maua           SP  4b70092fc12f2328972d5ff1022d87e9            4
# 9            maua           SP  b9e086024ceb0234e5950016497a4928            5
#
#    review_comment_title                             review_comment_message  \
# 0                   NaN  Não testei o produto ainda, mas ele veio corre...
# 1                   NaN  Não testei o produto ainda, mas ele veio corre...
# 2                   NaN  Não testei o produto ainda, mas ele veio corre...
# 3                   NaN  Deveriam embalar melhor o produto. A caixa vei...
# 4                   NaN  Só achei ela pequena pra seis xícaras ,mais é ...
# 5                   NaN                                                NaN
# 6                   NaN  Prezados que porcaria de atendimento ao client...
# 7                   NaN  Prezados que porcaria de atendimento ao client...
# 8                   NaN                                                NaN
# 9                   NaN                                                NaN
#
#   review_creation_date  review_answer_timestamp
# 0  2017-10-11 00:00:00      2017-10-12 03:43:48
# 1  2017-10-11 00:00:00      2017-10-12 03:43:48
# 2  2017-10-11 00:00:00      2017-10-12 03:43:48
# 3  2017-08-19 00:00:00      2017-08-20 15:16:36
# 4  2017-08-08 00:00:00      2017-08-08 23:26:23
# 5  2017-11-08 00:00:00      2017-11-10 19:52:38
# 6  2017-08-29 00:00:00      2017-08-30 02:26:02
# 7  2017-08-29 00:00:00      2017-08-30 02:26:02
# 8  2017-10-20 00:00:00      2017-10-23 04:13:41
# 9  2017-08-22 00:00:00      2017-08-26 02:31:53
#
# [10 rows x 40 columns]

# %%
orders.shape
# Out:
# (115609, 40)

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115609 entries, 0 to 115608
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       115609 non-null  object
#  1   customer_id                    115609 non-null  object
#  2   order_status                   115609 non-null  object
#  3   order_purchase_timestamp       115609 non-null  object
#  4   order_approved_at              115595 non-null  object
#  5   order_delivered_carrier_date   114414 non-null  object
#  6   order_delivered_customer_date  113209 non-null  object
#  7   order_estimated_delivery_date  115609 non-null  object
#  8   customer_unique_id             115609 non-null  object
#  9   customer_zip_code_prefix       115609 non-null  int64
#  10  customer_city                  115609 non-null  object
#  11  customer_state                 115609 non-null  object
#  12  order_item_id                  115609 non-null  int64
#  13  product_id                     115609 non-null  object
#  14  seller_id                      115609 non-null  object
#  15  shipping_limit_date            115609 non-null  object
#  16  price                          115609 non-null  float64
#  17  freight_value                  115609 non-null  float64
#  18  product_category_name          115609 non-null  object
#  19  product_name_lenght            115609 non-null  float64
#  20  product_description_lenght     115609 non-null  float64
#  21  product_photos_qty             115609 non-null  float64
#  22  product_weight_g               115608 non-null  float64
#  23  product_length_cm              115608 non-null  float64
#  24  product_height_cm              115608 non-null  float64
#  25  product_width_cm               115608 non-null  float64
#  26  product_category_name_english  115609 non-null  object
#  27  payment_sequential             115609 non-null  int64
#  28  payment_type                   115609 non-null  object
#  29  payment_installments           115609 non-null  int64
#  30  payment_value                  115609 non-null  float64
#  31  seller_zip_code_prefix         115609 non-null  int64
#  32  seller_city                    115609 non-null  object
#  33  seller_state                   115609 non-null  object
#  34  review_id                      115609 non-null  object
#  35  review_score                   115609 non-null  int64
#  36  review_comment_title           13801 non-null   object
#  37  review_comment_message         48906 non-null   object
#  38  review_creation_date           115609 non-null  object
#  39  review_answer_timestamp        115609 non-null  object
# dtypes: float64(10), int64(6), object(24)
# memory usage: 36.2+ MB

# %%
sum(orders.duplicated())
# Out:
# 0

# %%
orders.describe()
# Out:
#        customer_zip_code_prefix  order_item_id          price  freight_value  \
# count             115609.000000  115609.000000  115609.000000  115609.000000
# mean               35061.537597       1.194535     120.619850      20.056880
# std                29841.671732       0.685926     182.653476      15.836184
# min                 1003.000000       1.000000       0.850000       0.000000
# 25%                11310.000000       1.000000      39.900000      13.080000
# 50%                24241.000000       1.000000      74.900000      16.320000
# 75%                58745.000000       1.000000     134.900000      21.210000
# max                99980.000000      21.000000    6735.000000     409.680000
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count        115609.000000               115609.000000       115609.000000
# mean             48.766541                  785.808198            2.205373
# std              10.034187                  652.418619            1.717771
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  346.000000            1.000000
# 50%              52.000000                  600.000000            1.000000
# 75%              57.000000                  983.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count     115608.000000      115608.000000      115608.000000
# mean        2113.907697          30.307903          16.638477
# std         3781.754895          16.211108          13.473570
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1800.000000          38.000000          20.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm  payment_sequential  payment_installments  \
# count     115608.000000       115609.000000         115609.000000
# mean          23.113167            1.093747              2.946233
# std           11.755083            0.729849              2.781087
# min            6.000000            1.000000              0.000000
# 25%           15.000000            1.000000              1.000000
# 50%           20.000000            1.000000              2.000000
# 75%           30.000000            1.000000              4.000000
# max          118.000000           29.000000             24.000000
#
#        payment_value  seller_zip_code_prefix   review_score
# count  115609.000000           115609.000000  115609.000000
# mean      172.387379            24515.713958       4.034409
# std       265.873969            27636.640968       1.385584
# min         0.000000             1001.000000       1.000000
# 25%        60.870000             6429.000000       4.000000
# 50%       108.050000            13660.000000       5.000000
# 75%       189.480000            28605.000000       5.000000
# max     13664.080000            99730.000000       5.000000

# %%
orders.isnull().sum()
# Out:
# order_id                              0
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    14
# order_delivered_carrier_date       1195
# order_delivered_customer_date      2400
# order_estimated_delivery_date         0
# customer_unique_id                    0
# customer_zip_code_prefix              0
# customer_city                         0
# customer_state                        0
# order_item_id                         0
# product_id                            0
# seller_id                             0
# shipping_limit_date                   0
# price                                 0
# freight_value                         0
# product_category_name                 0
# product_name_lenght                   0
# product_description_lenght            0
# product_photos_qty                    0
# product_weight_g                      1
# product_length_cm                     1
# product_height_cm                     1
# product_width_cm                      1
# product_category_name_english         0
# payment_sequential                    0
# payment_type                          0
# payment_installments                  0
# payment_value                         0
# seller_zip_code_prefix                0
# seller_city                           0
# seller_state                          0
# review_id                             0
# review_score                          0
# review_comment_title             101808
# review_comment_message            66703
# review_creation_date                  0
# review_answer_timestamp               0
# dtype: int64

# %%
orders.isnull().sum() / orders.shape[0]
# Out:
# order_id                         0.000000
# customer_id                      0.000000
# order_status                     0.000000
# order_purchase_timestamp         0.000000
# order_approved_at                0.000121
# order_delivered_carrier_date     0.010337
# order_delivered_customer_date    0.020760
# order_estimated_delivery_date    0.000000
# customer_unique_id               0.000000
# customer_zip_code_prefix         0.000000
# customer_city                    0.000000
# customer_state                   0.000000
# order_item_id                    0.000000
# product_id                       0.000000
# seller_id                        0.000000
# shipping_limit_date              0.000000
# price                            0.000000
# freight_value                    0.000000
# product_category_name            0.000000
# product_name_lenght              0.000000
# product_description_lenght       0.000000
# product_photos_qty               0.000000
# product_weight_g                 0.000009
# product_length_cm                0.000009
# product_height_cm                0.000009
# product_width_cm                 0.000009
# product_category_name_english    0.000000
# payment_sequential               0.000000
# payment_type                     0.000000
# payment_installments             0.000000
# payment_value                    0.000000
# seller_zip_code_prefix           0.000000
# seller_city                      0.000000
# seller_state                     0.000000
# review_id                        0.000000
# review_score                     0.000000
# review_comment_title             0.880623
# review_comment_message           0.576971
# review_creation_date             0.000000
# review_answer_timestamp          0.000000
# dtype: float64

# %%
orders
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 4       0e7e841ddf8f8f2de2bad69267ecfbcf  26c7ac168e1433912a51b924fbd34d34
# ...                                  ...                               ...
# 115604  edcf1e1eeb52381be9388c90152be52d  ce2172509c4149d65212484eb761bc37
# 115605  2c12150c742ae2fa48bc703964c16c5f  ab0cf72dfe0538a63a57d6905ccb7b57
# 115606  9f7ba492c273ffac8f90a623b8eadd3b  c61336d6c835632048f973d2f2db598d
# 115607  2ef4a11b6e24fdfbb43b92cb5f95edff  ee1cfdc92e449920e25d3ca4ab4da4f6
# 115608  2ef4a11b6e24fdfbb43b92cb5f95edff  ee1cfdc92e449920e25d3ca4ab4da4f6
#
#        order_status order_purchase_timestamp    order_approved_at  \
# 0         delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1         delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2         delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3         delivered      2017-08-15 18:29:31  2017-08-15 20:05:16
# 4         delivered      2017-08-02 18:24:47  2017-08-02 18:43:15
# ...             ...                      ...                  ...
# 115604    delivered      2018-08-21 11:29:05  2018-08-21 11:50:47
# 115605    delivered      2018-07-28 17:55:27  2018-07-29 18:30:31
# 115606    delivered      2018-08-23 12:31:37  2018-08-24 03:24:24
# 115607    delivered      2018-07-23 18:35:14  2018-07-24 10:31:25
# 115608    delivered      2018-07-23 18:35:14  2018-07-24 10:31:25
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 0               2017-10-04 19:55:00           2017-10-10 21:25:13
# 1               2017-10-04 19:55:00           2017-10-10 21:25:13
# 2               2017-10-04 19:55:00           2017-10-10 21:25:13
# 3               2017-08-17 15:28:33           2017-08-18 14:44:43
# 4               2017-08-04 17:35:43           2017-08-07 18:30:01
# ...                             ...                           ...
# 115604          2018-08-21 15:37:00           2018-08-24 13:06:25
# 115605          2018-07-30 14:54:00           2018-08-03 17:46:46
# 115606          2018-08-24 15:14:00           2018-08-28 02:06:35
# 115607          2018-07-24 14:37:00           2018-07-27 14:04:10
# 115608          2018-07-24 14:37:00           2018-07-27 14:04:10
#
#        order_estimated_delivery_date                customer_unique_id  \
# 0                2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 1                2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 2                2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 3                2017-08-28 00:00:00  3a51803cc0d012c3b5dc8b7528cb05f7
# 4                2017-08-15 00:00:00  ef0996a1a279c26e7ecbd737be23d235
# ...                              ...                               ...
# 115604           2018-09-06 00:00:00  c5da6424f1f5decedef8672a1a0103e1
# 115605           2018-08-16 00:00:00  8c3c961a52bb5a0ffbce1d4e6d25cd67
# 115606           2018-09-03 00:00:00  428f4721a509be8c52de6ec2900ba918
# 115607           2018-08-06 00:00:00  8d80e477643ec569b24592ce3d9dfc4c
# 115608           2018-08-06 00:00:00  8d80e477643ec569b24592ce3d9dfc4c
#
#         customer_zip_code_prefix  ... payment_value seller_zip_code_prefix  \
# 0                           3149  ...         18.12                   9350
# 1                           3149  ...          2.00                   9350
# 2                           3149  ...         18.59                   9350
# 3                           3366  ...         37.77                   9350
# 4                           2290  ...         37.77                   9350
# ...                          ...  ...           ...                    ...
# 115604                     88350  ...        314.32                  95910
# 115605                     35930  ...         77.50                  17201
# 115606                     12305  ...         24.69                  17201
# 115607                      9951  ...         84.63                  17201
# 115608                      9951  ...         84.63                  17201
#
#         seller_city seller_state                         review_id  \
# 0              maua           SP  a54f0611adc9ed256b57ede6b6eb5114
# 1              maua           SP  a54f0611adc9ed256b57ede6b6eb5114
# 2              maua           SP  a54f0611adc9ed256b57ede6b6eb5114
# 3              maua           SP  b46f1e34512b0f4c74a72398b03ca788
# 4              maua           SP  dc90f19c2806f1abba9e72ad3c350073
# ...             ...          ...                               ...
# 115604      lajeado           RS  a6a6d2f97b28e8aca22046635855fe63
# 115605          jau           SP  6b7c670a784ae6d3f17ee1d4b28d197e
# 115606          jau           SP  24e88b5f641a6a3219ce7a730509d570
# 115607          jau           SP  ad0de1dda4fa03e8efb68c481b31ebf8
# 115608          jau           SP  ad0de1dda4fa03e8efb68c481b31ebf8
#
#        review_score  review_comment_title  \
# 0                 4                   NaN
# 1                 4                   NaN
# 2                 4                   NaN
# 3                 4                   NaN
# 4                 5                   NaN
# ...             ...                   ...
# 115604            5       Pedido entregue
# 115605            5                   NaN
# 115606            5                   NaN
# 115607            3     A FOLHA NAO FRISA
# 115608            3     A FOLHA NAO FRISA
#
#                                    review_comment_message  \
# 0       Não testei o produto ainda, mas ele veio corre...
# 1       Não testei o produto ainda, mas ele veio corre...
# 2       Não testei o produto ainda, mas ele veio corre...
# 3       Deveriam embalar melhor o produto. A caixa vei...
# 4       Só achei ela pequena pra seis xícaras ,mais é ...
# ...                                                   ...
# 115604  Recebi em 3 dias muito rápido tudo perfeito pa...
# 115605                                                NaN
# 115606                                          Excelente
# 115607  Um dos frisadores que comprei, especificamente...
# 115608  Um dos frisadores que comprei, especificamente...
#
#        review_creation_date  review_answer_timestamp
# 0       2017-10-11 00:00:00      2017-10-12 03:43:48
# 1       2017-10-11 00:00:00      2017-10-12 03:43:48
# 2       2017-10-11 00:00:00      2017-10-12 03:43:48
# 3       2017-08-19 00:00:00      2017-08-20 15:16:36
# 4       2017-08-08 00:00:00      2017-08-08 23:26:23
# ...                     ...                      ...
# 115604  2018-08-25 00:00:00      2018-08-27 16:43:30
# 115605  2018-08-04 00:00:00      2018-08-05 22:10:19
# 115606  2018-08-28 00:00:00      2018-08-31 00:26:10
# 115607  2018-07-28 00:00:00      2018-08-03 01:58:42
# 115608  2018-07-28 00:00:00      2018-08-03 01:58:42
#
# [115609 rows x 40 columns]

# %%
orders.isnull().sum()
# Out:
# order_id                              0
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    14
# order_delivered_carrier_date       1195
# order_delivered_customer_date      2400
# order_estimated_delivery_date         0
# customer_unique_id                    0
# customer_zip_code_prefix              0
# customer_city                         0
# customer_state                        0
# order_item_id                         0
# product_id                            0
# seller_id                             0
# shipping_limit_date                   0
# price                                 0
# freight_value                         0
# product_category_name                 0
# product_name_lenght                   0
# product_description_lenght            0
# product_photos_qty                    0
# product_weight_g                      1
# product_length_cm                     1
# product_height_cm                     1
# product_width_cm                      1
# product_category_name_english         0
# payment_sequential                    0
# payment_type                          0
# payment_installments                  0
# payment_value                         0
# seller_zip_code_prefix                0
# seller_city                           0
# seller_state                          0
# review_id                             0
# review_score                          0
# review_comment_title             101808
# review_comment_message            66703
# review_creation_date                  0
# review_answer_timestamp               0
# dtype: int64

# %%
orders.isnull().sum()/orders.shape[0]
# Out:
# order_id                         0.000000
# customer_id                      0.000000
# order_status                     0.000000
# order_purchase_timestamp         0.000000
# order_approved_at                0.000121
# order_delivered_carrier_date     0.010337
# order_delivered_customer_date    0.020760
# order_estimated_delivery_date    0.000000
# customer_unique_id               0.000000
# customer_zip_code_prefix         0.000000
# customer_city                    0.000000
# customer_state                   0.000000
# order_item_id                    0.000000
# product_id                       0.000000
# seller_id                        0.000000
# shipping_limit_date              0.000000
# price                            0.000000
# freight_value                    0.000000
# product_category_name            0.000000
# product_name_lenght              0.000000
# product_description_lenght       0.000000
# product_photos_qty               0.000000
# product_weight_g                 0.000009
# product_length_cm                0.000009
# product_height_cm                0.000009
# product_width_cm                 0.000009
# product_category_name_english    0.000000
# payment_sequential               0.000000
# payment_type                     0.000000
# payment_installments             0.000000
# payment_value                    0.000000
# seller_zip_code_prefix           0.000000
# seller_city                      0.000000
# seller_state                     0.000000
# review_id                        0.000000
# review_score                     0.000000
# review_comment_title             0.880623
# review_comment_message           0.576971
# review_creation_date             0.000000
# review_answer_timestamp          0.000000
# dtype: float64

# %%
orders['order_purchase_timestamp'] = pd.to_datetime(orders.order_purchase_timestamp).dt.date
orders['order_approved_at'] = pd.to_datetime(orders.order_approved_at).dt.date
orders['order_estimated_delivery_date'] = pd.to_datetime(orders.order_estimated_delivery_date).dt.date
orders['order_delivered_customer_date'] = pd.to_datetime(orders.order_delivered_customer_date).dt.date 
orders['review_answer_timestamp'] = pd.to_datetime(orders.review_answer_timestamp).dt.date
orders['review_creation_date'] = pd.to_datetime(orders.review_answer_timestamp).dt.date

# %%
orders.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 4  0e7e841ddf8f8f2de2bad69267ecfbcf  26c7ac168e1433912a51b924fbd34d34
# 5  bfc39df4f36c3693ff3b63fcbea9e90a  53904ddbea91e1e92b2b3f1d09a7af86
# 6  5f49f31e537f8f1a496454b48edbe34d  a7260a6ccba78544ccfaf43f920b7240
# 7  5f49f31e537f8f1a496454b48edbe34d  a7260a6ccba78544ccfaf43f920b7240
# 8  1fa40f202d5d233b6491e976c557b822  50fd5707c28d0a64dc20d67f937dd9ba
# 9  41c045db2d1876be9f05cf4a787693b2  a286f46d6e54cc0179bbb0ee07b0df5e
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered               2017-10-02        2017-10-02
# 1    delivered               2017-10-02        2017-10-02
# 2    delivered               2017-10-02        2017-10-02
# 3    delivered               2017-08-15        2017-08-15
# 4    delivered               2017-08-02        2017-08-02
# 5    delivered               2017-10-23        2017-10-25
# 6    delivered               2017-08-24        2017-08-24
# 7    delivered               2017-08-24        2017-08-24
# 8    delivered               2017-09-23        2017-09-23
# 9    delivered               2017-08-16        2017-08-16
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00                    2017-10-10
# 1          2017-10-04 19:55:00                    2017-10-10
# 2          2017-10-04 19:55:00                    2017-10-10
# 3          2017-08-17 15:28:33                    2017-08-18
# 4          2017-08-04 17:35:43                    2017-08-07
# 5          2017-10-27 16:48:46                    2017-11-07
# 6          2017-08-25 14:17:55                    2017-08-28
# 7          2017-08-25 14:17:55                    2017-08-28
# 8          2017-09-26 17:27:54                    2017-10-19
# 9          2017-08-18 15:41:40                    2017-08-21
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 2                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 3                    2017-08-28  3a51803cc0d012c3b5dc8b7528cb05f7
# 4                    2017-08-15  ef0996a1a279c26e7ecbd737be23d235
# 5                    2017-11-13  e781fdcc107d13d865fc7698711cc572
# 6                    2017-09-14  7a1de9bde89aedca8c5fbad489c5571c
# 7                    2017-09-14  7a1de9bde89aedca8c5fbad489c5571c
# 8                    2017-11-13  35c6ec4630637b3ec0da6e587f245f83
# 9                    2017-08-29  4e4fa2b85379e9db6dc59f873f0a9748
#
#    customer_zip_code_prefix  ... payment_value seller_zip_code_prefix  \
# 0                      3149  ...         18.12                   9350
# 1                      3149  ...          2.00                   9350
# 2                      3149  ...         18.59                   9350
# 3                      3366  ...         37.77                   9350
# 4                      2290  ...         37.77                   9350
# 5                     88032  ...         44.09                   9350
# 6                      1315  ...        127.45                   9350
# 7                      1315  ...        127.45                  14021
# 8                     69043  ...         50.05                   9350
# 9                      5640  ...         32.68                   9350
#
#       seller_city seller_state                         review_id review_score  \
# 0            maua           SP  a54f0611adc9ed256b57ede6b6eb5114            4
# 1            maua           SP  a54f0611adc9ed256b57ede6b6eb5114            4
# 2            maua           SP  a54f0611adc9ed256b57ede6b6eb5114            4
# 3            maua           SP  b46f1e34512b0f4c74a72398b03ca788            4
# 4            maua           SP  dc90f19c2806f1abba9e72ad3c350073            5
# 5            maua           SP  1bafb430e498b939f258b9c9dbdff9b1            3
# 6            maua           SP  8899ca945efd951c97107b4966289227            1
# 7  ribeirao preto           SP  8899ca945efd951c97107b4966289227            1
# 8            maua           SP  4b70092fc12f2328972d5ff1022d87e9            4
# 9            maua           SP  b9e086024ceb0234e5950016497a4928            5
#
#    review_comment_title                             review_comment_message  \
# 0                   NaN  Não testei o produto ainda, mas ele veio corre...
# 1                   NaN  Não testei o produto ainda, mas ele veio corre...
# 2                   NaN  Não testei o produto ainda, mas ele veio corre...
# 3                   NaN  Deveriam embalar melhor o produto. A caixa vei...
# 4                   NaN  Só achei ela pequena pra seis xícaras ,mais é ...
# 5                   NaN                                                NaN
# 6                   NaN  Prezados que porcaria de atendimento ao client...
# 7                   NaN  Prezados que porcaria de atendimento ao client...
# 8                   NaN                                                NaN
# 9                   NaN                                                NaN
#
#   review_creation_date  review_answer_timestamp
# 0           2017-10-12               2017-10-12
# 1           2017-10-12               2017-10-12
# 2           2017-10-12               2017-10-12
# 3           2017-08-20               2017-08-20
# 4           2017-08-08               2017-08-08
# 5           2017-11-10               2017-11-10
# 6           2017-08-30               2017-08-30
# 7           2017-08-30               2017-08-30
# 8           2017-10-23               2017-10-23
# 9           2017-08-26               2017-08-26
#
# [10 rows x 40 columns]

# %%
orders.shape
# Out:
# (115609, 40)

# %%
cont_columns = list(orders.select_dtypes(include=[np.number]).columns.values)
cat_columns = list(orders.select_dtypes(include=['object']).columns.values)

# %% [markdown]
# ##3. Data Visualizations

# %%
sns.set_theme(style = "darkgrid")

# %%
eda.numerical_plots(orders, cont_columns, normality_check = True)
# Out:
# **1. Plot for customer_zip_code_prefix**
# **2. Plot for order_item_id**
# **3. Plot for price**
# **4. Plot for freight_value**
# **5. Plot for product_name_lenght**
# **6. Plot for product_description_lenght**
# **7. Plot for product_photos_qty**
# **8. Plot for product_weight_g**
# **9. Plot for product_length_cm**
# **10. Plot for product_height_cm**
# **11. Plot for product_width_cm**
# **12. Plot for payment_sequential**
# **13. Plot for payment_installments**
# **14. Plot for payment_value**
# **15. Plot for seller_zip_code_prefix**
# **16. Plot for review_score**

# %%
fig = px.pie(orders['customer_state'], names = orders['customer_state'].value_counts().index,
             values = orders['customer_state'].value_counts().values,
             title = 'Customer State')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ad03caec-d117-42ba-9e1c-76c14de5686d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad03caec-d117-42ba-9e1c-76c14de5686d")) {                    Plotly.newPlot(                        "ad03caec-d117-42ba-9e1c-76c14de5686d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["SP","RJ","MG","RS","PR","SC","BA","DF","GO","ES","PE","CE","MT","PA","MS","MA","PB","PI","RN","AL","SE","TO","RO","AM","AC","AP","RR"],"legendgroup":"","name":"","showlegend":true,"values":[48797,14987,13429,6413,5879,4218,3942,2449,2359,2300,1851,1527,1106,1081,845,832,619,561,560,455,393,333,279,168,93,83,50],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scatt ...

# %%
fig = px.pie(orders['review_score'], names = orders['review_score'].value_counts().index,
             values = orders['review_score'].value_counts().values,
             title = 'Review Scores')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="87a009d6-9157-4545-9ab3-371bd665e940" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87a009d6-9157-4545-9ab3-371bd665e940")) {                    Plotly.newPlot(                        "87a009d6-9157-4545-9ab3-371bd665e940",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":[5,4,1,3,2],"legendgroup":"","name":"","showlegend":true,"values":[65374,21951,14546,9718,4020],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10 ...

# %%
items_reviews = pd.merge(order_reviews, order_items, how='left', on='order_id')
review_qty = items_reviews.groupby('review_score').size()
review_value = items_reviews.groupby('review_score')['price'].mean()

# %%
trace0 = go.Bar(
    x=review_qty.index,
    y=review_qty.values,
    name='Number of orders',
    marker=dict(color='rgb(49,130,189)')
)
trace1 = go.Bar(
    x=review_value.index,
    y=review_value.values,
    name='Product mean value',
    marker=dict(color='rgb(204,204,204)')
)
fig = make_subplots(rows=1, cols=2, print_grid=False)
fig.append_trace(trace0, 1, 1)
fig.append_trace(trace1, 1, 2)

fig['layout'].update(height=400, width=800, title='Review Score')
fig['layout']['xaxis1'].update(title='review score', domain=[0, 0.40], tickmode = 'linear')
fig['layout']['xaxis2'].update(title='review score', domain=[0.6, 1], tickmode = 'linear')
iplot(fig);
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="571f1d60-0384-4b6f-b33e-2d46823db8e1" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("571f1d60-0384-4b6f-b33e-2d46823db8e1")) {                    Plotly.newPlot(                        "571f1d60-0384-4b6f-b33e-2d46823db8e1",                        [{"marker":{"color":"rgb(49,130,189)"},"name":"Number of orders","x":[1,2,3,4,5],"xaxis":"x","y":[14775,3936,9476,21348,63596],"yaxis":"y","type":"bar"},{"marker":{"color":"rgb(204,204,204)"},"name":"Product mean value","x":[1,2,3,4,5],"xaxis":"x2","y":[127.35006814190376,115.84913784202375,110.05970391595034,118.60262772695286,121.21982510822511],"yaxis":"y2","type":"bar"}],                        {"height":400,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marke ...

# %%
fig, ax = plt.subplots(figsize = (13, 13))
plt.title("Pearson Correlation Heatmap")
sns.heatmap(orders.corr(method = 'pearson'), annot = True, cmap = 'icefire')
plt.show()
# Out:
# <ipython-input-36-664a6fac9793>:3: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
orders_df['order_purchase_timestamp'] = pd.to_datetime(orders_df['order_purchase_timestamp'])
orders_df['order_approved_at'] = pd.to_datetime(orders_df['order_approved_at'])
orders_df['order_estimated_delivery_date'] = pd.to_datetime(orders_df['order_estimated_delivery_date'])
orders_df['order_delivered_customer_date'] = pd.to_datetime(orders_df['order_delivered_customer_date'])
orders_df['delivery_time'] = (orders_df['order_delivered_customer_date'] - orders_df['order_approved_at']).dt.total_seconds() / 86400
orders_df['estimated_delivery_time'] = (orders_df['order_estimated_delivery_date'] - orders_df['order_approved_at']).dt.total_seconds() / 86400
plt.figure(figsize=(10,4))
plt.title("Delivery time in days")
plt.xlim(-10, 200)

ax1 = sns.kdeplot(orders_df['delivery_time'].dropna(), color="#D84E30", label='Delivery time')
ax2 = sns.kdeplot(orders_df['estimated_delivery_time'].dropna(), color="#7E7270", label='Estimated delivery time')

# %%
top_ordersbyvalue_cities = orders.groupby("customer_city")["payment_value"].sum().reset_index().sort_values("payment_value", ascending=False)
top_ordersbyvalue_cities["% of Total Payments"] = (top_ordersbyvalue_cities["payment_value"] / top_ordersbyvalue_cities["payment_value"].sum()) * 100
top_ordersbyvalue_cities["Cum % of Total Payments"] = top_ordersbyvalue_cities["% of Total Payments"].cumsum()

# %%
fig = px.bar(top_ordersbyvalue_cities[:10], x = "% of Total Payments", y = "customer_city", 
             title = "Highest 10 cities by revenue generation")
fig.update_layout(yaxis={'categoryorder':'total ascending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="27cd0351-e69f-4f24-849a-5002747bce22" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27cd0351-e69f-4f24-849a-5002747bce22")) {                    Plotly.newPlot(                        "27cd0351-e69f-4f24-849a-5002747bce22",                        [{"alignmentgroup":"True","hovertemplate":"% of Total Payments=%{x}<br>customer_city=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[14.087264866850239,7.708900999057554,2.472551526233744,2.147748824514574,1.6452311663607764,1.5620159178345003,1.412688782338472,1.3151152441734397,1.0010461610175754,0.8732382458043108],"xaxis":"x","y":["sao paulo","rio de janeiro","belo horizonte","brasilia","curitiba","porto alegre","salvador","campinas","guarulhos","niteroi"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"e ...

# %%
fig = px.bar(top_ordersbyvalue_cities[-10:], x = "% of Total Payments", y = "customer_city", 
             title = "Lowest 10 cities by revenue generation")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5bd20065-1cd7-40ac-a5dc-cb1e8d01894c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bd20065-1cd7-40ac-a5dc-cb1e8d01894c")) {                    Plotly.newPlot(                        "5bd20065-1cd7-40ac-a5dc-cb1e8d01894c",                        [{"alignmentgroup":"True","hovertemplate":"% of Total Payments=%{x}<br>customer_city=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.00013186460846484983,0.0001309112494234373,0.00012970700642375832,0.00012594374704976146,0.00012483985763338905,0.0001215783661759251,0.00012087589109277902,0.000113299195553132,0.00010386595872231323,0.00010246100855602108],"xaxis":"x","y":["frecheirinha","nova resende","planaltina do parana","bom jardim de goias","erico cardoso","santo antonio do rio abaixo","tamboara","jenipapo de minas","polo petroquimico de triunfo","sabaudia"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"sca ...

# %%
plt.figure(figsize=(6,6))
reviewsocres = orders.groupby("product_category_name_english")["review_score"].agg(["mean", "count"]).sort_values(by="mean",ascending=False)
bestrated = reviewsocres[reviewsocres["count"]>=30][:10]
bestrated
fig = px.bar(bestrated, x = bestrated.values[0:, 0], y = bestrated.index, 
             title = "Highest 10 rated items categories")
fig.update_layout(yaxis={'categoryorder':'total ascending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="0f420e89-dc78-4ddf-9b67-ed7ccdbb6d64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f420e89-dc78-4ddf-9b67-ed7ccdbb6d64")) {                    Plotly.newPlot(                        "0f420e89-dc78-4ddf-9b67-ed7ccdbb6d64",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>product_category_name_english=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[4.438502673796791,4.419354838709677,4.419354838709677,4.415841584158416,4.37546468401487,4.324137931034483,4.32051282051282,4.295944779982744,4.258064516129032,4.228962818003914],"xaxis":"x","y":["books_general_interest","books_imported","flowers","costruction_tools_tools","books_technical","food_drink","small_appliances_home_oven_and_coffee","luggage_accessories","fashion_sport","food"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth": ...

# %%
plt.figure(figsize=(6,6))
worstrated = reviewsocres[reviewsocres["count"]>=30].sort_values(by='mean')[:10]
fig = px.bar(worstrated, x = worstrated.values[0:, 0], y = worstrated.index, 
             title = "Lowest 10 rated items categories")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="cb1f60f1-a428-49af-a6db-1f41c17846e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb1f60f1-a428-49af-a6db-1f41c17846e6")) {                    Plotly.newPlot(                        "cb1f60f1-a428-49af-a6db-1f41c17846e6",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>product_category_name_english=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[3.2564102564102564,3.526790750141004,3.548611111111111,3.6728624535315983,3.78,3.8048780487804876,3.8408488063660475,3.8412698412698414,3.847826086956522,3.8484848484848486],"xaxis":"x","y":["diapers_and_hygiene","office_furniture","fashion_male_clothing","fixed_telephony","fashio_female_clothing","furniture_mattress_and_upholstery","audio","furniture_bedroom","party_supplies","construction_tools_safety"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar ...

# %%
merged_groups = orders.groupby('customer_city')['payment_value'].sum().reset_index().sort_values('payment_value', ascending = False)
plt.figure(figsize = (12, 12))
fig = px.bar(merged_groups[:10], x = "customer_city", y='payment_value', title = 'Payment Value on the basis of State')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="cbbbd25e-8429-4c71-907e-856068884b5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cbbbd25e-8429-4c71-907e-856068884b5d")) {                    Plotly.newPlot(                        "cbbbd25e-8429-4c71-907e-856068884b5d",                        [{"alignmentgroup":"True","hovertemplate":"customer_city=%{x}<br>payment_value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["sao paulo","rio de janeiro","belo horizonte","brasilia","curitiba","porto alegre","salvador","campinas","guarulhos","niteroi"],"xaxis":"x","y":[2807526.03,1536347.93,492767.96,428036.3,327886.88,311302.47000000003,281542.27,262096.32,199503.82,174032.3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"patte ...

# %%
merged_groups = orders.groupby('product_category_name_english')['payment_value'].sum().reset_index().sort_values('payment_value', ascending = False)
plt.figure(figsize = (15, 15))
fig = px.bar(merged_groups[:10], x = "product_category_name_english", y='payment_value', title = 'Payment Value on the basis Product Value')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d987969a-58dd-470d-85bc-4f6e67f8f9ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d987969a-58dd-470d-85bc-4f6e67f8f9ba")) {                    Plotly.newPlot(                        "d987969a-58dd-470d-85bc-4f6e67f8f9ba",                        [{"alignmentgroup":"True","hovertemplate":"product_category_name_english=%{x}<br>payment_value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["bed_bath_table","health_beauty","computers_accessories","furniture_decor","watches_gifts","sports_leisure","housewares","garden_tools","auto","cool_stuff"],"xaxis":"x","y":[1725465.67,1646292.53,1592611.66,1427214.01,1420682.17,1390581.87,1091709.15,834757.45,802254.74,772616.7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"li ...

# %%
scorevstime = orders.groupby(pd.to_datetime(orders.order_purchase_timestamp).dt.year)["review_score"].mean().dropna()
plt.figure(figsize=(6,6))
fig = px.bar(scorevstime, x = scorevstime.index , y = scorevstime.values, 
             title = "Mean Review Score on Yearly Basis")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="951d6e11-2e63-40a0-be2c-94df36619d7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("951d6e11-2e63-40a0-be2c-94df36619d7d")) {                    Plotly.newPlot(                        "951d6e11-2e63-40a0-be2c-94df36619d7d",                        [{"alignmentgroup":"True","hovertemplate":"order_purchase_timestamp=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2016,2017,2018],"xaxis":"x","y":[3.6036745406824147,4.051250309482545,4.022926930374197],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpo ...

# %% [markdown]
# ## 4. Feature Enigneering 1

# %%
orders.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 4  0e7e841ddf8f8f2de2bad69267ecfbcf  26c7ac168e1433912a51b924fbd34d34
# 5  bfc39df4f36c3693ff3b63fcbea9e90a  53904ddbea91e1e92b2b3f1d09a7af86
# 6  5f49f31e537f8f1a496454b48edbe34d  a7260a6ccba78544ccfaf43f920b7240
# 7  5f49f31e537f8f1a496454b48edbe34d  a7260a6ccba78544ccfaf43f920b7240
# 8  1fa40f202d5d233b6491e976c557b822  50fd5707c28d0a64dc20d67f937dd9ba
# 9  41c045db2d1876be9f05cf4a787693b2  a286f46d6e54cc0179bbb0ee07b0df5e
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered               2017-10-02        2017-10-02
# 1    delivered               2017-10-02        2017-10-02
# 2    delivered               2017-10-02        2017-10-02
# 3    delivered               2017-08-15        2017-08-15
# 4    delivered               2017-08-02        2017-08-02
# 5    delivered               2017-10-23        2017-10-25
# 6    delivered               2017-08-24        2017-08-24
# 7    delivered               2017-08-24        2017-08-24
# 8    delivered               2017-09-23        2017-09-23
# 9    delivered               2017-08-16        2017-08-16
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00                    2017-10-10
# 1          2017-10-04 19:55:00                    2017-10-10
# 2          2017-10-04 19:55:00                    2017-10-10
# 3          2017-08-17 15:28:33                    2017-08-18
# 4          2017-08-04 17:35:43                    2017-08-07
# 5          2017-10-27 16:48:46                    2017-11-07
# 6          2017-08-25 14:17:55                    2017-08-28
# 7          2017-08-25 14:17:55                    2017-08-28
# 8          2017-09-26 17:27:54                    2017-10-19
# 9          2017-08-18 15:41:40                    2017-08-21
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 2                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 3                    2017-08-28  3a51803cc0d012c3b5dc8b7528cb05f7
# 4                    2017-08-15  ef0996a1a279c26e7ecbd737be23d235
# 5                    2017-11-13  e781fdcc107d13d865fc7698711cc572
# 6                    2017-09-14  7a1de9bde89aedca8c5fbad489c5571c
# 7                    2017-09-14  7a1de9bde89aedca8c5fbad489c5571c
# 8                    2017-11-13  35c6ec4630637b3ec0da6e587f245f83
# 9                    2017-08-29  4e4fa2b85379e9db6dc59f873f0a9748
#
#    customer_zip_code_prefix  ... payment_value seller_zip_code_prefix  \
# 0                      3149  ...         18.12                   9350
# 1                      3149  ...          2.00                   9350
# 2                      3149  ...         18.59                   9350
# 3                      3366  ...         37.77                   9350
# 4                      2290  ...         37.77                   9350
# 5                     88032  ...         44.09                   9350
# 6                      1315  ...        127.45                   9350
# 7                      1315  ...        127.45                  14021
# 8                     69043  ...         50.05                   9350
# 9                      5640  ...         32.68                   9350
#
#       seller_city seller_state                         review_id review_score  \
# 0            maua           SP  a54f0611adc9ed256b57ede6b6eb5114            4
# 1            maua           SP  a54f0611adc9ed256b57ede6b6eb5114            4
# 2            maua           SP  a54f0611adc9ed256b57ede6b6eb5114            4
# 3            maua           SP  b46f1e34512b0f4c74a72398b03ca788            4
# 4            maua           SP  dc90f19c2806f1abba9e72ad3c350073            5
# 5            maua           SP  1bafb430e498b939f258b9c9dbdff9b1            3
# 6            maua           SP  8899ca945efd951c97107b4966289227            1
# 7  ribeirao preto           SP  8899ca945efd951c97107b4966289227            1
# 8            maua           SP  4b70092fc12f2328972d5ff1022d87e9            4
# 9            maua           SP  b9e086024ceb0234e5950016497a4928            5
#
#    review_comment_title                             review_comment_message  \
# 0                   NaN  Não testei o produto ainda, mas ele veio corre...
# 1                   NaN  Não testei o produto ainda, mas ele veio corre...
# 2                   NaN  Não testei o produto ainda, mas ele veio corre...
# 3                   NaN  Deveriam embalar melhor o produto. A caixa vei...
# 4                   NaN  Só achei ela pequena pra seis xícaras ,mais é ...
# 5                   NaN                                                NaN
# 6                   NaN  Prezados que porcaria de atendimento ao client...
# 7                   NaN  Prezados que porcaria de atendimento ao client...
# 8                   NaN                                                NaN
# 9                   NaN                                                NaN
#
#   review_creation_date  review_answer_timestamp
# 0           2017-10-12               2017-10-12
# 1           2017-10-12               2017-10-12
# 2           2017-10-12               2017-10-12
# 3           2017-08-20               2017-08-20
# 4           2017-08-08               2017-08-08
# 5           2017-11-10               2017-11-10
# 6           2017-08-30               2017-08-30
# 7           2017-08-30               2017-08-30
# 8           2017-10-23               2017-10-23
# 9           2017-08-26               2017-08-26
#
# [10 rows x 40 columns]

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115609 entries, 0 to 115608
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       115609 non-null  object
#  1   customer_id                    115609 non-null  object
#  2   order_status                   115609 non-null  object
#  3   order_purchase_timestamp       115609 non-null  object
#  4   order_approved_at              115595 non-null  object
#  5   order_delivered_carrier_date   114414 non-null  object
#  6   order_delivered_customer_date  113209 non-null  object
#  7   order_estimated_delivery_date  115609 non-null  object
#  8   customer_unique_id             115609 non-null  object
#  9   customer_zip_code_prefix       115609 non-null  int64
#  10  customer_city                  115609 non-null  object
#  11  customer_state                 115609 non-null  object
#  12  order_item_id                  115609 non-null  int64
#  13  product_id                     115609 non-null  object
#  14  seller_id                      115609 non-null  object
#  15  shipping_limit_date            115609 non-null  object
#  16  price                          115609 non-null  float64
#  17  freight_value                  115609 non-null  float64
#  18  product_category_name          115609 non-null  object
#  19  product_name_lenght            115609 non-null  float64
#  20  product_description_lenght     115609 non-null  float64
#  21  product_photos_qty             115609 non-null  float64
#  22  product_weight_g               115608 non-null  float64
#  23  product_length_cm              115608 non-null  float64
#  24  product_height_cm              115608 non-null  float64
#  25  product_width_cm               115608 non-null  float64
#  26  product_category_name_english  115609 non-null  object
#  27  payment_sequential             115609 non-null  int64
#  28  payment_type                   115609 non-null  object
#  29  payment_installments           115609 non-null  int64
#  30  payment_value                  115609 non-null  float64
#  31  seller_zip_code_prefix         115609 non-null  int64
#  32  seller_city                    115609 non-null  object
#  33  seller_state                   115609 non-null  object
#  34  review_id                      115609 non-null  object
#  35  review_score                   115609 non-null  int64
#  36  review_comment_title           13801 non-null   object
#  37  review_comment_message         48906 non-null   object
#  38  review_creation_date           115609 non-null  object
#  39  review_answer_timestamp        115609 non-null  object
# dtypes: float64(10), int64(6), object(24)
# memory usage: 36.2+ MB

# %%
recency = orders.groupby(by = 'customer_unique_id', as_index = False)['order_purchase_timestamp'].max()
recency.rename(columns = {"order_purchase_timestamp":"LastPurchaseDate"}, inplace=True)
recency["LastPurchaseDate"] =  pd.to_datetime(recency.LastPurchaseDate).dt.date

recent_date = pd.to_datetime(orders.order_purchase_timestamp).dt.date.max()
recency['Recency'] = recency['LastPurchaseDate'].apply(lambda x: (recent_date - x).days)

# %%
recency
# Out:
#                      customer_unique_id LastPurchaseDate  Recency
# 0      0000366f3b9a7992bf8c76cfdf3221e2       2018-05-10      116
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f       2018-05-07      119
# 2      0000f46a3911fa3c0805444483337064       2017-03-10      542
# 3      0000f6ccb0745a6a4b88665a16c9f078       2017-10-12      326
# 4      0004aac84e0df4da2b147fca70cf8255       2017-11-14      293
# ...                                 ...              ...      ...
# 93391  fffcf5a5ff07b0908bd4e2dbc735a684       2017-06-08      452
# 93392  fffea47cd6d3cc0a88bd621562a9d061       2017-12-10      267
# 93393  ffff371b4d645b6ecea244b27531430a       2017-02-07      573
# 93394  ffff5962728ec6157033ef9805bacc48       2018-05-02      124
# 93395  ffffd2657e2aad2907e67c3e9daecbeb       2017-05-02      489
#
# [93396 rows x 3 columns]

# %%
frequency = orders.groupby(["customer_unique_id"]).agg({"order_id":"nunique"}).reset_index()
frequency.rename(columns={"order_id":"Frequency"}, inplace=True)

# %%
frequency
# Out:
#                      customer_unique_id  Frequency
# 0      0000366f3b9a7992bf8c76cfdf3221e2          1
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f          1
# 2      0000f46a3911fa3c0805444483337064          1
# 3      0000f6ccb0745a6a4b88665a16c9f078          1
# 4      0004aac84e0df4da2b147fca70cf8255          1
# ...                                 ...        ...
# 93391  fffcf5a5ff07b0908bd4e2dbc735a684          1
# 93392  fffea47cd6d3cc0a88bd621562a9d061          1
# 93393  ffff371b4d645b6ecea244b27531430a          1
# 93394  ffff5962728ec6157033ef9805bacc48          1
# 93395  ffffd2657e2aad2907e67c3e9daecbeb          1
#
# [93396 rows x 2 columns]

# %%
monetary = orders.groupby('customer_unique_id', as_index=False)['payment_value'].sum()
monetary.columns = ['customer_unique_id', 'Monetary']

# %%
monetary
# Out:
#                      customer_unique_id  Monetary
# 0      0000366f3b9a7992bf8c76cfdf3221e2    141.90
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f     27.19
# 2      0000f46a3911fa3c0805444483337064     86.22
# 3      0000f6ccb0745a6a4b88665a16c9f078     43.62
# 4      0004aac84e0df4da2b147fca70cf8255    196.89
# ...                                 ...       ...
# 93391  fffcf5a5ff07b0908bd4e2dbc735a684   4134.84
# 93392  fffea47cd6d3cc0a88bd621562a9d061     84.58
# 93393  ffff371b4d645b6ecea244b27531430a    112.46
# 93394  ffff5962728ec6157033ef9805bacc48    133.69
# 93395  ffffd2657e2aad2907e67c3e9daecbeb     71.56
#
# [93396 rows x 2 columns]

# %%
rf = recency.merge(frequency, on='customer_unique_id')
rfm = rf.merge(monetary, on='customer_unique_id').drop(columns='LastPurchaseDate')
rfm.head()
# Out:
#                  customer_unique_id  Recency  Frequency  Monetary
# 0  0000366f3b9a7992bf8c76cfdf3221e2      116          1    141.90
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f      119          1     27.19
# 2  0000f46a3911fa3c0805444483337064      542          1     86.22
# 3  0000f6ccb0745a6a4b88665a16c9f078      326          1     43.62
# 4  0004aac84e0df4da2b147fca70cf8255      293          1    196.89

# %%
rfm[rfm.columns[1:]] = rfm[rfm.columns[1:]].applymap(lambda x: 1 if x ==0 else x)

# %%
def check_skew(df_skew, column):
    skew = stats.skew(df_skew[column])
    skewtest = stats.skewtest(df_skew[column])
    plt.title('Distribution of ' + column)
    sns.distplot(df_skew[column])
    plt.show()
    print("{}'s: Skew: {}, : {}".format(column, skew, skewtest))
    return

# %%
for col in rfm.columns[1:]:
    check_skew(rfm, col)
# Out:
# <ipython-input-56-31a94896c4d8>:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Recency's: Skew: 0.4525743664936904, : SkewtestResult(statistic=53.91755466635981, pvalue=0.0)
# <ipython-input-56-31a94896c4d8>:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Frequency's: Skew: 10.990942154921314, : SkewtestResult(statistic=335.6456861541721, pvalue=0.0)
# <ipython-input-56-31a94896c4d8>:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Monetary's: Skew: 70.33621193560055, : SkewtestResult(statistic=524.6379205104615, pvalue=0.0)

# %%
rfm_log = rfm.copy()
for c in rfm.columns[1:]:
    rfm_log[c] = np.log10(rfm_log[c])

# %%
for col in rfm.columns[1:]:
    check_skew(rfm_log, col)
# Out:
# <ipython-input-56-31a94896c4d8>:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Recency's: Skew: -1.0782500114150588, : SkewtestResult(statistic=-111.14545442314179, pvalue=0.0)
# <ipython-input-56-31a94896c4d8>:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Frequency's: Skew: 6.068294981630156, : SkewtestResult(statistic=275.4417097222108, pvalue=0.0)
# <ipython-input-56-31a94896c4d8>:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Monetary's: Skew: 0.729609897634013, : SkewtestResult(statistic=81.9204555191681, pvalue=0.0)

# %%
rfm_log
# Out:
#                      customer_unique_id   Recency  Frequency  Monetary
# 0      0000366f3b9a7992bf8c76cfdf3221e2  2.064458        0.0  2.151982
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f  2.075547        0.0  1.434409
# 2      0000f46a3911fa3c0805444483337064  2.733999        0.0  1.935608
# 3      0000f6ccb0745a6a4b88665a16c9f078  2.513218        0.0  1.639686
# 4      0004aac84e0df4da2b147fca70cf8255  2.466868        0.0  2.294224
# ...                                 ...       ...        ...       ...
# 93391  fffcf5a5ff07b0908bd4e2dbc735a684  2.655138        0.0  3.616459
# 93392  fffea47cd6d3cc0a88bd621562a9d061  2.426511        0.0  1.927268
# 93393  ffff371b4d645b6ecea244b27531430a  2.758155        0.0  2.050998
# 93394  ffff5962728ec6157033ef9805bacc48  2.093422        0.0  2.126099
# 93395  ffffd2657e2aad2907e67c3e9daecbeb  2.689309        0.0  1.854670
#
# [93396 rows x 4 columns]

# %%
rfm_log.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93396 entries, 0 to 93395
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_unique_id  93396 non-null  object
#  1   Recency             93396 non-null  float64
#  2   Frequency           93396 non-null  float64
#  3   Monetary            93396 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 3.6+ MB

# %%
def pipe(X):
  X_num_col = X.select_dtypes(include = ([np.number])).columns.values
  X_num_cat = X.select_dtypes(include = (['object'])).columns.values

  cat_cols = X_num_cat
  cont_cols = X_num_col 
  
  full_pipe = ColumnTransformer(transformers = [('onehot_enc', OneHotEncoder(), cat_cols), ('std_scl', StandardScaler(), cont_cols)],
                                remainder = 'passthrough')
  
  X_pipe = full_pipe.fit_transform(X)

  return X_pipe

# %%
rfm_done = pipe(rfm_log)

# %% [markdown]
# ## 5. Data Modelling (Clustering)

# %%
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(rfm_done)
    distortions.append(kmeanModel.inertia_)

plt.figure(figsize=(9,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
kmean_model = KMeans(n_clusters = 4, random_state = 10)
kmean_y = kmean_model.fit_predict(rfm_done)

# %%
def rfm_values(df):
    df_new = df.groupby(['Cluster']).agg({
            'Recency': 'mean',
            'Frequency': 'mean',
            'Monetary': ['mean', 'count']
        }).round(0)

    return df_new

# %%
rfm['Cluster'] = kmean_model.labels_

# %%
rfm
# Out:
#                      customer_unique_id  Recency  Frequency  Monetary  Cluster
# 0      0000366f3b9a7992bf8c76cfdf3221e2      116          1    141.90        1
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      119          1     27.19        0
# 2      0000f46a3911fa3c0805444483337064      542          1     86.22        0
# 3      0000f6ccb0745a6a4b88665a16c9f078      326          1     43.62        0
# 4      0004aac84e0df4da2b147fca70cf8255      293          1    196.89        2
# ...                                 ...      ...        ...       ...      ...
# 93391  fffcf5a5ff07b0908bd4e2dbc735a684      452          1   4134.84        2
# 93392  fffea47cd6d3cc0a88bd621562a9d061      267          1     84.58        0
# 93393  ffff371b4d645b6ecea244b27531430a      573          1    112.46        0
# 93394  ffff5962728ec6157033ef9805bacc48      124          1    133.69        0
# 93395  ffffd2657e2aad2907e67c3e9daecbeb      489          1     71.56        0
#
# [93396 rows x 5 columns]

# %%
#rfm.to_csv('engage.csv')

# %%
rfm_values(rfm)
# Out:
#         Recency Frequency Monetary
#            mean      mean     mean  count
# Cluster
# 0         298.0       1.0     77.0  45578
# 1          51.0       1.0    144.0  17574
# 2         275.0       1.0    457.0  27437
# 3         226.0       2.0    488.0   2807

# %% [markdown]
# ### RFM Analysis
#
#
# ##### RFM stands for recency, frequency, monetary value. In business analytics, we often use this concept to divide customers into different segments, like high-value customers, medium value customers or low-value customers, and similarly many others.
#
# ##### Recency: How recently has the customer made a transaction with the company until end of session.
#
# ##### Frequency: How frequent is the customer in ordering/buying some product from the company
#
# ##### Monetary: How much does the customer spend on purchasing products from the company.

# %% [markdown]
# ### Cluster Analysis
#
# #### Cluster 0 : These are Low spenders in this cluster. Customers in this cluster seem have one of the highest recency and their monetary value is low. This cluster shouldn't be the focus of marketing effort.
#
# #### Cluster 1 : These are the  New Comers in this cluster as their spending is the smallest among all clusters but have the lowest recency. This cluster is quite huge. So, some marketing effort could be advisable towards it in order to increase its monetary value.
#
# #### Cluster 2 : These are the Big spenders cluster as it's recency comes second and the average amount spent is largest. This cluster is also second in terms of number of customers.
#
# #### Cluster 3 : These are  the Loyal customers in this cluster haven't on average ordered in a while, their frequency of orders is greater than all other clusters and the value of their orders is quite high.

# %% [markdown]
# ## 6. Feature Engineering 2

# %%
rfm
# Out:
#                      customer_unique_id  Recency  Frequency  Monetary  Cluster
# 0      0000366f3b9a7992bf8c76cfdf3221e2      116          1    141.90        1
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      119          1     27.19        0
# 2      0000f46a3911fa3c0805444483337064      542          1     86.22        0
# 3      0000f6ccb0745a6a4b88665a16c9f078      326          1     43.62        0
# 4      0004aac84e0df4da2b147fca70cf8255      293          1    196.89        2
# ...                                 ...      ...        ...       ...      ...
# 93391  fffcf5a5ff07b0908bd4e2dbc735a684      452          1   4134.84        2
# 93392  fffea47cd6d3cc0a88bd621562a9d061      267          1     84.58        0
# 93393  ffff371b4d645b6ecea244b27531430a      573          1    112.46        0
# 93394  ffff5962728ec6157033ef9805bacc48      124          1    133.69        0
# 93395  ffffd2657e2aad2907e67c3e9daecbeb      489          1     71.56        0
#
# [93396 rows x 5 columns]

# %%
rfm.shape, rfm.columns
# Out:
# ((93396, 5),
#  Index(['customer_unique_id', 'Recency', 'Frequency', 'Monetary', 'Cluster'], dtype='object'))

# %%
cont_columns = list(rfm.select_dtypes(include=[np.number]).columns.values)
cont_columns
# Out:
# ['Recency', 'Frequency', 'Monetary', 'Cluster']

# %%
fig = px.pie(rfm['Cluster'], names = rfm['Cluster'].value_counts().index,
             values = rfm['Cluster'].value_counts().values,
             title = 'Cluster Percentage')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="75d7fbde-081e-4698-a176-475c7ef13ae8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75d7fbde-081e-4698-a176-475c7ef13ae8")) {                    Plotly.newPlot(                        "75d7fbde-081e-4698-a176-475c7ef13ae8",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":[0,2,1,3],"legendgroup":"","name":"","showlegend":true,"values":[45578,27437,17574,2807],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solid ...

# %%
eda.numerical_plots(rfm, cont_columns, normality_check = True)
# Out:
# **1. Plot for Recency**
# **2. Plot for Frequency**
# **3. Plot for Monetary**
# **4. Plot for Cluster**

# %%
for col in rfm.columns[1:4]:
    check_skew(rfm, col)
# Out:
# <ipython-input-56-31a94896c4d8>:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Recency's: Skew: 0.4525743664936904, : SkewtestResult(statistic=53.91755466635981, pvalue=0.0)
# <ipython-input-56-31a94896c4d8>:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Frequency's: Skew: 10.990942154921314, : SkewtestResult(statistic=335.6456861541721, pvalue=0.0)
# <ipython-input-56-31a94896c4d8>:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Monetary's: Skew: 70.33621193560055, : SkewtestResult(statistic=524.6379205104615, pvalue=0.0)

# %%
rfm_log_new = rfm.copy()
for c in rfm.columns[1:4]:
    rfm_log_new[c] = np.log10(rfm_log_new[c])

# %%
for col in rfm.columns[1:4]:
    check_skew(rfm_log_new, col)
# Out:
# <ipython-input-56-31a94896c4d8>:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Recency's: Skew: -1.0782500114150588, : SkewtestResult(statistic=-111.14545442314179, pvalue=0.0)
# <ipython-input-56-31a94896c4d8>:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Frequency's: Skew: 6.068294981630156, : SkewtestResult(statistic=275.4417097222108, pvalue=0.0)
# <ipython-input-56-31a94896c4d8>:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Monetary's: Skew: 0.729609897634013, : SkewtestResult(statistic=81.9204555191681, pvalue=0.0)

# %%
rfm_log_new
# Out:
#                      customer_unique_id   Recency  Frequency  Monetary  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2  2.064458        0.0  2.151982
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f  2.075547        0.0  1.434409
# 2      0000f46a3911fa3c0805444483337064  2.733999        0.0  1.935608
# 3      0000f6ccb0745a6a4b88665a16c9f078  2.513218        0.0  1.639686
# 4      0004aac84e0df4da2b147fca70cf8255  2.466868        0.0  2.294224
# ...                                 ...       ...        ...       ...
# 93391  fffcf5a5ff07b0908bd4e2dbc735a684  2.655138        0.0  3.616459
# 93392  fffea47cd6d3cc0a88bd621562a9d061  2.426511        0.0  1.927268
# 93393  ffff371b4d645b6ecea244b27531430a  2.758155        0.0  2.050998
# 93394  ffff5962728ec6157033ef9805bacc48  2.093422        0.0  2.126099
# 93395  ffffd2657e2aad2907e67c3e9daecbeb  2.689309        0.0  1.854670
#
#        Cluster
# 0            1
# 1            0
# 2            0
# 3            0
# 4            2
# ...        ...
# 93391        2
# 93392        0
# 93393        0
# 93394        0
# 93395        0
#
# [93396 rows x 5 columns]

# %%
eda.numerical_check_outliers(rfm_log_new, list(rfm_log_new.select_dtypes(include=[np.number]).columns.values), tol=1.5, print_vars = False)
# Out:
#            lower_bound_outliers  upper_bound_outliers  total_outliers  \
# Recency                    3369                     0            3369
# Frequency                     0                  2807            2807
# Monetary                      3                  1840            1843
# Cluster                       0                     0               0
#
#            perc_outliers
# Recency         3.607221
# Frequency       3.005482
# Monetary        1.973318
# Cluster         0.000000

# %%
outliers = eda.numerical_check_outliers(rfm_log_new, list(rfm_log_new.select_dtypes(include=[np.number]).columns.values), tol=1.5, print_vars = False)
per = outliers['perc_outliers']
tot = outliers['total_outliers']

# %%
fig = px.bar(per, x = per.index, y = per.values, title = "Outliers on Basis of Percentage")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d75a04f6-2e82-4b97-a2a1-3b84bec235d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d75a04f6-2e82-4b97-a2a1-3b84bec235d3")) {                    Plotly.newPlot(                        "d75a04f6-2e82-4b97-a2a1-3b84bec235d3",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Recency","Frequency","Monetary","Cluster"],"xaxis":"x","y":[3.6072208659899783,3.0054820334917984,1.9733179151141378,0.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":"" ...

# %%
fig = px.bar(tot, x = tot.index, y = tot.values, title = "Outliers on Basis of Count")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b638adc7-5888-4872-bc73-23a45be6d827" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b638adc7-5888-4872-bc73-23a45be6d827")) {                    Plotly.newPlot(                        "b638adc7-5888-4872-bc73-23a45be6d827",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Recency","Frequency","Monetary","Cluster"],"xaxis":"x","y":[3369,2807,1843,0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar", ...

# %%
elpenv = EllipticEnvelope(contamination=0.025, random_state=1)
  # Returns 1 of inliers, -1 for outliers
pred = elpenv.fit_predict(rfm_log_new[list(rfm_log_new.select_dtypes(include=[np.number]).columns.values)])

anom_index = np.where(pred==-1)
rem = rfm_log_new.loc[anom_index]

rem
# Out:
#                      customer_unique_id   Recency  Frequency  Monetary  \
# 120    004b45ec5c64187465168251cd1c9c2f  2.000000   0.301030  2.169439
# 140    0058f300f57d7b93c477a131a59b36c3  2.217484   0.301030  2.244475
# 243    00a39521eb40f7012db50455bf083460  1.963788   0.301030  2.090787
# 305    00cc12a6d8b578b8ebd21ea4e2ae8b27  2.725095   0.301030  2.402089
# 404    011575986092c30523ecb71ff10cb473  2.139879   0.301030  2.332236
# ...                                 ...       ...        ...       ...
# 93071  ff22e30958c13ffe219db7d711e8f564  0.000000   0.301030  2.522340
# 93123  ff44401d0d8f5b9c54a47374eb48c1b8  2.673942   0.301030  1.832509
# 93228  ff8892f7c26aa0446da53d01b18df463  2.448706   0.301030  2.598659
# 93244  ff922bdd6bafcdf99cb90d7f39cea5b3  2.549003   0.477121  2.144885
# 93352  ffe254cc039740e17dd15a5305035928  2.715167   0.301030  1.903741
#
#        Cluster
# 120          3
# 140          3
# 243          3
# 305          3
# 404          3
# ...        ...
# 93071        3
# 93123        3
# 93228        3
# 93244        3
# 93352        3
#
# [2335 rows x 5 columns]

# %%
rfm_log_new.drop(index = rem.index, axis = 0, inplace = True)

# %%
rfm_log_new.shape
# Out:
# (91061, 5)

# %%
X = rfm_log_new.drop('Cluster', axis = 1)
y = rfm_log_new['Cluster']

# %%
type(X), type(y)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
c
# Out:
# 'Monetary'

# %%
X.head(10)
# Out:
#                  customer_unique_id   Recency  Frequency  Monetary
# 0  0000366f3b9a7992bf8c76cfdf3221e2  2.064458        0.0  2.151982
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f  2.075547        0.0  1.434409
# 2  0000f46a3911fa3c0805444483337064  2.733999        0.0  1.935608
# 3  0000f6ccb0745a6a4b88665a16c9f078  2.513218        0.0  1.639686
# 4  0004aac84e0df4da2b147fca70cf8255  2.466868        0.0  2.294224
# 5  0004bd2a26a76fe21f786e4fbd80607f  2.178977        0.0  2.222664
# 6  00050ab1314c0e55a6ca13cf7181fecf  2.133539        0.0  1.548758
# 7  00053a61a98854899e70ed204dd4bafe  2.271842        0.0  2.923431
# 8  0005e1862207bf6ccc02e4228effd9a0  2.738781        0.0  2.176439
# 9  0005ef4cd20d2893f0d9fbd94d3c0d97  2.243038        0.0  2.113141

# %%
y.head(10)
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    2
# 5    2
# 6    0
# 7    2
# 8    0
# 9    0
# Name: Cluster, dtype: int32

# %%
X.dtypes
# Out:
# customer_unique_id     object
# Recency               float64
# Frequency             float64
# Monetary              float64
# dtype: object

# %%
X_cols = X.select_dtypes(include = ([np.number])).columns.values
X_cats = X.select_dtypes(include = (['object'])).columns.values

# %%
X_cols, X_cats
# Out:
# (array(['Recency', 'Frequency', 'Monetary'], dtype=object),
#  array(['customer_unique_id'], dtype=object))

# %%
full_pipe = ColumnTransformer(transformers = [('ord_enc', OrdinalEncoder(), X_cats), ('std_scl', StandardScaler(), X_cols)],
                                remainder = 'passthrough')
  
X_pipe = full_pipe.fit_transform(X)

X_pipe
# Out:
# array([[ 0.00000000e+00, -5.05150655e-01, -7.22595470e-02,
#          1.89307431e-01],
#        [ 1.00000000e+00, -4.76302196e-01, -7.22595470e-02,
#         -1.63107491e+00],
#        [ 2.00000000e+00,  1.23669108e+00, -7.22595470e-02,
#         -3.59603956e-01],
#        ...,
#        [ 9.10580000e+04,  1.29953227e+00, -7.22595470e-02,
#         -6.68755882e-02],
#        [ 9.10590000e+04, -4.29800300e-01, -7.22595470e-02,
#          1.23644699e-01],
#        [ 9.10600000e+04,  1.12042693e+00, -7.22595470e-02,
#         -5.64931493e-01]])

# %%
X_rfm =  X_pipe
X_rfm
# Out:
# array([[ 0.00000000e+00, -5.05150655e-01, -7.22595470e-02,
#          1.89307431e-01],
#        [ 1.00000000e+00, -4.76302196e-01, -7.22595470e-02,
#         -1.63107491e+00],
#        [ 2.00000000e+00,  1.23669108e+00, -7.22595470e-02,
#         -3.59603956e-01],
#        ...,
#        [ 9.10580000e+04,  1.29953227e+00, -7.22595470e-02,
#         -6.68755882e-02],
#        [ 9.10590000e+04, -4.29800300e-01, -7.22595470e-02,
#          1.23644699e-01],
#        [ 9.10600000e+04,  1.12042693e+00, -7.22595470e-02,
#         -5.64931493e-01]])

# %%
X_rfm.shape, y.shape
# Out:
# ((91061, 4), (91061,))

# %%
sm = SMOTE()
X_sm, y_sm = sm.fit_resample(X_rfm, y)

# %%
fig = px.pie(y, names = y.value_counts().index,
             values = y.value_counts().values,
             title = 'Before SMOTE Process')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d822584c-2449-488e-b38e-bafd018eb8db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d822584c-2449-488e-b38e-bafd018eb8db")) {                    Plotly.newPlot(                        "d822584c-2449-488e-b38e-bafd018eb8db",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":[0,2,1,3],"legendgroup":"","name":"","showlegend":true,"values":[45578,27436,17574,473],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidi ...

# %%
fig = px.pie(y_sm, names = y_sm.value_counts().index,
             values = y_sm.value_counts().values,
             title = 'After SMOTE Process')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b91bfb39-12e1-4987-92db-f6b0ea0ae7d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b91bfb39-12e1-4987-92db-f6b0ea0ae7d5")) {                    Plotly.newPlot(                        "b91bfb39-12e1-4987-92db-f6b0ea0ae7d5",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":[1,0,2,3],"legendgroup":"","name":"","showlegend":true,"values":[45578,45578,45578,45578],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"soli ...

# %%
X_sm.shape, y_sm.shape
# Out:
# ((182312, 4), (182312,))

# %%
X_train, X_test, y_train , y_test = tts(X_sm, y_sm, test_size= .33, random_state = 10)

# %%
# X_train, X_test, y_train, y_test = evalml.preprocessing.split_data(X_sm, y_sm, test_size = .33, 
#                                                                    problem_type = 'Multiclass')

# %%
X_train.shape, y_train.shape
# Out:
# ((122149, 4), (122149,))

# %%
X_test.shape, y_test.shape
# Out:
# ((60163, 4), (60163,))

# %% [markdown]
# ## 7. Data Modeling (Classification)

# %% [markdown]
# ### AutoML (Discarded)

# %%
#evalml.objectives.get_all_objective_names()

# %%
'''
automl_mc = AutoMLSearch(X_train = X_train, y_train = y_train, problem_type = 'Multiclass', objective = 'accuracy multiclass', 
                         max_batches = 1, verbose = True)
automl_mc.search(interactive_plot = False)
'''
# Out:
# "\nautoml_mc = AutoMLSearch(X_train = X_train, y_train = y_train, problem_type = 'Multiclass', objective = 'accuracy multiclass', \n                         max_batches = 1, verbose = True)\nautoml_mc.search(interactive_plot = False)\n"

# %%
#automl_mc.rankings

# %%
#automl_mc.describe_pipeline(automl_mc.rankings.iloc[0]['id'])

# %%
'''
best_pipe = automl_mc.best_pipeline
best_pipe
'''
# Out:
# '\nbest_pipe = automl_mc.best_pipeline\nbest_pipe\n'

# %%
#y_pred_aml = best_pipe.predict(X_test)

# %%
'''
scores = best_pipe.score(X_train, y_train, objectives = evalml.objectives.get_core_objectives('Multiclass'))
print(f' The Accuracy of AutoMLSearch for Test Set is  : {scores["Accuracy Multiclass"]}')
'''
# Out:
# '\nscores = best_pipe.score(X_train, y_train, objectives = evalml.objectives.get_core_objectives(\'Multiclass\'))\nprint(f\' The Accuracy of AutoMLSearch for Test Set is  : {scores["Accuracy Multiclass"]}\')\n'

# %%
'''
scores = best_pipe.score(X_test, y_test, objectives = evalml.objectives.get_core_objectives('Multiclass'))
print(f' The Accuracy of AutoMLSearch for Test Set is  : {scores["Accuracy Multiclass"]}')
'''
# Out:
# '\nscores = best_pipe.score(X_test, y_test, objectives = evalml.objectives.get_core_objectives(\'Multiclass\'))\nprint(f\' The Accuracy of AutoMLSearch for Test Set is  : {scores["Accuracy Multiclass"]}\')\n'

# %%
'''
plt.figure(figsize=(10,10))
plt.title("AutoMLSearch Confusion Matrix")
sns.heatmap(confusion_matrix(y_test,y_pred_aml), annot = True, cmap ='icefire')
plt.ylabel("Actual Vlues")
plt.xlabel("Predicted Vlues")
plt.show()
'''
# Out:
# '\nplt.figure(figsize=(10,10))\nplt.title("AutoMLSearch Confusion Matrix")\nsns.heatmap(confusion_matrix(y_test,y_pred_aml), annot = True, cmap =\'icefire\')\nplt.ylabel("Actual Vlues")\nplt.xlabel("Predicted Vlues")\nplt.show()\n'

# %% [markdown]
# ### RandomForest Classifier

# %%
model_rfc=RandomForestClassifier(n_jobs= -1, max_depth = 15, min_samples_split= 5, 
                                 random_state= 10, n_estimators= 200)

model_rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=15, min_samples_split=5, n_estimators=200,
#                        n_jobs=-1, random_state=10)

# %%
y_pred_rfc = model_rfc.predict(X_test)

# %%
train_acc_rfc = model_rfc.score(X_train, y_train)
print("The Accuracy for Training Set is {}".format(train_acc_rfc*100))
# Out:
# The Accuracy for Training Set is 100.0

# %%
test_acc_rfc = accuracy_score(y_test, y_pred_rfc)
print("The Accuracy for Test Set is {}".format(test_acc_rfc*100))
# Out:
# The Accuracy for Test Set is 99.93850040722704

# %%
print(classification_report(y_test, y_pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     15004
#            1       1.00      1.00      1.00     15168
#            2       1.00      1.00      1.00     14950
#            3       1.00      1.00      1.00     15041
#
#     accuracy                           1.00     60163
#    macro avg       1.00      1.00      1.00     60163
# weighted avg       1.00      1.00      1.00     60163

# %%
plt.figure(figsize=(10,10))
plt.title("Random Forest Classifier Confusion Matrix")
sns.heatmap(confusion_matrix(y_test,y_pred_rfc), annot = True, cmap ='icefire')
plt.ylabel("Actual Values")
plt.xlabel("Predicted Values")
plt.show()

# %%
input_data = [('0000366f3b9a7992bf8c76cfdf3221e2',	116,	1,	141.90)]

# %%
ex = pd.DataFrame(input_data, columns = ['customer_unique_id', 'Recency', 'Frequency', 'Monetary'])
ex
# Out:
#                  customer_unique_id  Recency  Frequency  Monetary
# 0  0000366f3b9a7992bf8c76cfdf3221e2      116          1     141.9

# %%
for c in ex.columns[1:4]:
    ex[c] = np.log10(ex[c])

ex
# Out:
#                  customer_unique_id   Recency  Frequency  Monetary
# 0  0000366f3b9a7992bf8c76cfdf3221e2  2.064458        0.0  2.151982

# %%
scale_ex = full_pipe.transform(ex)

# %%
prdctn = model_rfc.predict(scale_ex)
prdctn
# Out:
# array([1], dtype=int32)

# %% [markdown]
# ## 8. Save Model

# %%
filename = 'prop_engage_model.p'

# %%
pickle.dump(model_rfc, open(filename, 'wb'))
